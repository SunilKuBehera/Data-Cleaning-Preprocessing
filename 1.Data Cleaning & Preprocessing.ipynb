# %% [markdown]
# ## 1. Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Load the dataset

# %%
df=pd.read_csv("Life Expectancy Data.csv")

# %%
df.head() # checking top 5 data for now
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.tail() # shows bottom 5 record
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %% [markdown]
# ## 3. Sanity check for the data

# %%
# Shape of the data
df.shape
# Out:
# (2938, 22)

# %%
# Information about the data
df.info
# Out:
# <bound method DataFrame.info of           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Check percentage of missing values from each coulumn
df.isnull().sum()/df.shape[0]*100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check datatypes
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
for col in df.select_dtypes(include="object").columns:
    print(f"\n Columns: {col}")
    
    # Strip whitespace and convert to lowercase for consistency
    cleaned_col = df[col].astype(str).str.strip().str.lower()
    
    # Replace empty strings with NaN
    cleaned_col = cleaned_col.replace("", pd.NA)
    
    # Show value counts including NaNs
    print("Value Counts (including NaNs):")
    print(cleaned_col.value_counts(dropna=False))
    
    # Show number of unique values
    print(f"Unique values: {cleaned_col.nunique(dropna=False)}")
    
    # Show number of nulls
    print(f"Nulls (NaNs): {cleaned_col.isna().sum()}")
    
    print("=" * 50)
# Out:
#  Columns: Country
# Value Counts (including NaNs):
# Country
# afghanistan              16
# peru                     16
# nicaragua                16
# niger                    16
# nigeria                  16
#                          ..
# niue                      1
# san marino                1
# nauru                     1
# saint kitts and nevis     1
# dominica                  1
# Name: count, Length: 193, dtype: int64
# Unique values: 193
# Nulls (NaNs): 0
# ...
#
#  Columns: Status
# Value Counts (including NaNs):
# Status
# developing    2426
# developed      512
# Name: count, dtype: int64
# Unique values: 2
# Nulls (NaNs): 0
# ...

# %% [markdown]
# ## 4. Data Exploration

# %%
# Describe the data
df.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          2938  2938.000000        2938       2928.000000
# unique          193          NaN           2               NaN
# top     Afghanistan          NaN  Developing               NaN
# freq             16          NaN        2426               NaN
# mean            NaN  2007.518720         NaN         69.224932
# std             NaN     4.613841         NaN          9.523867
# min             NaN  2000.000000         NaN         36.300000
# 25%             NaN  2004.000000         NaN         63.100000
# 50%             NaN  2008.000000         NaN         72.100000
# 75%             NaN  2012.000000         NaN         75.700000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2928.000000    2938.000000  2744.000000             2938.000000
# ...

# %% [markdown]
# - Histogram to understand the data

# %%
# Set a consistent style
sns.set(style="whitegrid")

# Get numeric columns
numeric_cols = df.select_dtypes(include='number').columns

# Set up subplot grid
num_cols = len(numeric_cols)
cols_per_row = 3
rows = (num_cols + cols_per_row - 1) // cols_per_row
plt.figure(figsize=(5 * cols_per_row, 4 * rows))
for idx, col in enumerate(numeric_cols, 1):
    plt.subplot(rows, cols_per_row, idx)
    sns.histplot(df[col].dropna(), kde=True, bins=30, color='skyblue')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# - Boxplot to identify Outliers

# %%
# Set Seaborn style
sns.set(style="whitegrid")

# Define color
color = ['skyblue']

# Get numeric columns
numeric_cols = df.select_dtypes(include='number').columns
num_cols = len(numeric_cols)

# Set up subplot grid
cols_per_row = 3
rows = (num_cols + cols_per_row - 1) // cols_per_row
plt.figure(figsize=(6 * cols_per_row, 5 * rows))

for idx, col in enumerate(numeric_cols, 1):
    plt.subplot(rows, cols_per_row, idx)
    
    # Choose a vibrant color for each boxplot
    colors = color[(idx - 1) % len(color)]
    
    sns.boxplot(data=df, x=col, color=colors)
    plt.title(f"Boxplot of {col}", fontsize=12)
    plt.xlabel(col)
    plt.tight_layout()

plt.suptitle("Boxplots to Detect Outliers", fontsize=16, y=1.02)
plt.show()

# %%
def find_outliers(series, method="IQR", factor=1.5):
    if method == "IQR":
        Q1 = series.quantile(0.25)
        Q3 = series.quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR
        return (series < lower_bound) | (series > upper_bound)
    else:
        raise ValueError("Unsupported method. Use 'IQR'.")

# Loop through numeric columns and print outlier counts
for col in df.select_dtypes(include="number").columns:
    mask = find_outliers(df[col].dropna())
    count = mask.sum()
    total = len(df[col])
    print(f"{col} : {count} Outliers out of {total} values , Outlier Percentage : ({count/total:.2%})")
# Out:
# Year : 0 Outliers out of 2938 values , Outlier Percentage : (0.00%)
# Life expectancy  : 10 Outliers out of 2938 values , Outlier Percentage : (0.34%)
# Adult Mortality : 82 Outliers out of 2938 values , Outlier Percentage : (2.79%)
# infant deaths : 315 Outliers out of 2938 values , Outlier Percentage : (10.72%)
# Alcohol : 0 Outliers out of 2938 values , Outlier Percentage : (0.00%)
# percentage expenditure : 389 Outliers out of 2938 values , Outlier Percentage : (13.24%)
# Hepatitis B : 254 Outliers out of 2938 values , Outlier Percentage : (8.65%)
# Measles  : 542 Outliers out of 2938 values , Outlier Percentage : (18.45%)
#  BMI  : 0 Outliers out of 2938 values , Outlier Percentage : (0.00%)
# under-five deaths  : 394 Outliers out of 2938 values , Outlier Percentage : (13.41%)
# Polio : 279 Outliers out of 2938 values , Outlier Percentage : (9.50%)
# Total expenditure : 32 Outliers out of 2938 values , Outlier Percentage : (1.09%)
# ...

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# - Scatter plot to understand the relationship among columns

# %%
# Scatter plot for the life expectancy
for i in ['Year', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
    
    sns.scatterplot(data=df,x=i,y='Life expectancy ')
    plt.show()

# %% [markdown]
# - Correlation

# %%
# Correlation with heatmap to interpret the relation and multicolliniarity
plt.figure(figsize=(15,15))
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True)
plt.show()

# %% [markdown]
# ## 5. Data Preprocessing

# %% [markdown]
# -  Missing Value Treatment

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.dtypes
# Out:
# Country                             object
# Year                               float64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                      float64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                            float64
#  BMI                               float64
# under-five deaths                  float64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
# Fill missing values in categorical columns with mode
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Fill missing values in numerical columns
for col in df.select_dtypes(include='float64').columns:
    if df[col].isnull().sum() > 0:
        # Use median if data is skewed, otherwise mean
        skewness = df[col].skew()
        if abs(skewness) > 1:
            df[col].fillna(df[col].median(), inplace=True)
        else:
            df[col].fillna(df[col].mean(), inplace=True)

# %%
df.isnull().sum()  # Should show all zeros
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# - Outlier Treatment

# %%
# Outlier treatment using IQR capping
# Create a copy of the original DataFrame
df_before = df.copy()

# Apply IQR-based outlier capping
for col in df.select_dtypes(include='float64').columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = df[col].apply(lambda x: 
                            lower_bound if x < lower_bound else 
                            upper_bound if x > upper_bound else x)

# %%
# Plot before and after boxplots in subplots
cols_to_plot = ['GDP', 'Total expenditure']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 16))
fig.suptitle('Outlier Treatment: Before vs After', fontsize=16)

for i, col in enumerate(cols_to_plot):
    # Before
    sns.boxplot(data=df_before[col], ax=axes[i][0], color='salmon')
    axes[i][0].set_title(f'{col} - Before')
    
    # After
    sns.boxplot(data=df[col], ax=axes[i][1], color='lightgreen')
    axes[i][1].set_title(f'{col} - After')

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %% [markdown]
# - Encode the data

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Step 1: Label Encode 'Country'
le = LabelEncoder()
df['Country'] = le.fit_transform(df['Country'])

# Step 2: One-Hot Encode 'Status'
df = pd.get_dummies(df, columns=['Status'], drop_first=True)

# %% [markdown]
# - Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# Step 1: Identify numerical columns
num_cols = df.select_dtypes(include='float64').columns

# Step 2: Initialize scaler
scaler = StandardScaler()

# Step 3: Apply scaling
df[num_cols] = scaler.fit_transform(df[num_cols])
